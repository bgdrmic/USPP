# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
from functools import *
from selenium import webdriver
import time
from datetime import datetime

# %%
original_csv = 'combined_articles.csv'

home_url = 'https://hjp.znanje.hr/'
search_url = 'https://hjp.znanje.hr/index.php?show=search'

noun_tags = ['m', 'ž', 'sr']
verb_tags = ['svrš.', 'nesvrš.', 'dv.']


multiple_entries_found_string = 'Pronađeno je više natuknica koje odgovaraju zadanom uvjetu:'
no_entries_found_string = 'Nijedna natuknica u rječničkoj bazi ne zadovoljava zadane uvjete'
extract_prefix = True

allowed_types = [noun_tags]
allowed_types = reduce(lambda a, b: a+b, allowed_types)

# %%
def read_dict():
    df = pd.read_csv('dictionary_index_articles.csv').fillna('')
    return df.to_dict()
    
def save_dict(d):
    k = np.array(list(d.keys()))
    v = np.array(list(d.values()))
    df = pd.DataFrame(np.stack([k, v], axis=-1))
    df.to_csv('dictionary_' + original_csv, index=False)

try:
    dictionary = read_dict()
except FileNotFoundError:
    dictionary = {'': ''}

# %%
def extract_prefix(word, do_extract):
    if not do_extract:
        return word
    
    l = len(word)
    if l > 10:
        return word[:8]
    elif l > 7:
        return word[:5]
    elif l > 5:
        return word[:3]
    elif l > 3:
        return word[:2]
    return word
    
    
def _normalize_word_req(word, extract_prefix):
    word_page = requests.post(search_url, data={'word': word}).content
    if multiple_entries_found_string in word_page.decode("utf-8"):
        soup = BeautifulSoup(word_page)
        element = soup.find('div', class_= 'container content grey')
        link = home_url + element.find('a')['href']
        word_page = requests.get(link).content
    elif no_entries_found_string in word_page.decode("utf-8"):
        return extract_prefix(word, extract_prefix)
    try:
        soup = BeautifulSoup(word_page)
        element = soup.find('div', class_= 'container content grey').find('div').find('div')
        header = element.find_all('p')[1]
        word_type = header.find('i').text
        if word_type not in allowed_types:
            word_normal = ''
        else:
            word_normal = header.find('b').text
    except (AttributeError, IndexError):
        word_normal = ''
        word_type = ''
        
    return word_normal


def normalize_word(word, extract_prefix=True):
    if word in dictionary:
        return dictionary.get(word)
    
    normalized = _normalize_word_req(word, extract_prefix)
    dictionary[word] = normalized
    return normalized


def filter_and_normalize(words, extract_prefix=True):
    normalized = list(map(lambda word: normalize_word(word, extract_prefix), words))
    filtered = list(filter(lambda x: x != '', normalized))
    return filtered

def normalize_text(text):
    try:
        words = re.split('[<>()\[\]{}|\\/-_,.;:!?\"\' \n\t]', text)
        normalized = filter_and_normalize(words, extract_prefix)
#     print(normalized)
    
        return reduce(lambda a, b: a + ' ' + b, normalized)
    except TypeError:
#         print(normalized)
        return ''

# %%
database = pd.read_csv(original_csv)
texts = database['content']
mod_texts = [[] for _ in texts]
for i, text in enumerate(texts):
    start = time.time()
    mod_texts[i] = normalize_text(text)
    end = time.time()
    print("Time {}: {}".format(i, end - start))
    save_dict(dictionary)
# modified_database.to_csv('modified_' + original_csv, index=False)
database['modified'] = mod_texts
database.to_csv('modified.csv', index = False)
# Out:
# Time 0: 0.0019910335540771484
# Time 1: 0.0020666122436523438
# Time 2: 0.0
# Time 3: 0.0
# Time 4: 0.0
# Time 5: 0.0
# Time 6: 0.0019941329956054688
# Time 113: 0.00299072265625
# Time 114: 0.0012345314025878906
# Time 115: 0.0
# Time 116: 0.0009853839874267578
# Time 117: 0.0
# Time 118: 0.001001119613647461
# Time 119: 0.0009968280792236328
# Time 120: 0.0009975433349609375
# Time 121: 0.0009989738464355469
# Time 122: 0.0
# Time 123: 0.0
# Time 124: 0.0
# Time 125: 0.0
# Time 126: 0.0
# Time 127: 0.0009937286376953125
# Time 128: 0.0009965896606445312
# Time 129: 0.0
# Time 130: 0.0009963512420654297
# Time 131: 0.002048969268798828
# Time 132: 0.0009970664978027344
# Time 133: 0.0
# Time 134: 0.0019931793212890625
# Time 135: 0.0
# Time 136: 0.0
# Time 137: 0.0009982585906982422
# Time 138: 0.0
# Time 139: 0.0
# Time 140: 0.0009965896606445312
# Time 141: 0.0029532909393310547
# Time 142: 0.0009963512420654297
# Time 143: 0.0
# Time 144: 0.0
# Time 145: 0.0
# Time 146: 0.0009942054748535156
# Time 147: 0.0009837150573730469
# Time 148: 0.001940011978149414
# Time 149: 0.0009942054748535156
# Time 150: 0.0009925365447998047
# Time 151: 0.0
# Time 152: 0.0009963512420654297
# Time 153: 0.00299072265625
# Time 154: 0.0009982585906982422
# Time 155: 0.0019452571868896484
# Time 156: 0.0009963512420654297
# Time 157: 0.0009970664978027344
# Time 158: 0.0019931793212890625
# Time 159: 0.0
# Time 160: 0.0019936561584472656
# Time 161: 0.008147239685058594
# Time 162: 0.001988649368286133
# Time 163: 0.0
# Time 164: 0.0009276866912841797
# Time 165: 0.001992940902709961
# Time 166: 0.0019910335540771484
# Time 167: 0.001001596450805664
# Time 168: 0.001993417739868164
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21884/365459412.py in normalize_text(text)
#      57     try:
# ---> 58         words = re.split('[<>()\[\]{}|\\/-_,.;:!?\"\' \n\t]', text)
#      59         normalized = filter_and_normalize(words, extract_prefix)
#
# ~\AppData\Local\Programs\Python\Python39\lib\re.py in split(pattern, string, maxsplit, flags)
#     230     of the list."""
# --> 231     return _compile(pattern, flags).split(string, maxsplit)
#     232
#
# TypeError: expected string or bytes-like object
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21884/773799155.py in <module>
#       4 for i, text in enumerate(texts):
#       5     start = time.time()
# ----> 6     mod_texts[i] = normalize_text(text)
#       7     end = time.time()
#       8     print("Time {}: {}".format(i, end - start))
#
# ~\AppData\Local\Temp/ipykernel_21884/365459412.py in normalize_text(text)
#      62         return reduce(lambda a, b: a + ' ' + b, normalized)
#      63     except TypeError:
# ---> 64         print(words)
#      65 #         print(normalized)
#      66         return ''
#
# UnboundLocalError: local variable 'words' referenced before assignment

# %%
for i, text in enumerate(texts[170:]):
    i += 170
    start = time.time()
    mod_texts[i] = normalize_text(text)
    end = time.time()
    print("Time {}: {}".format(i, end - start))
    save_dict(dictionary)
# modified_database.to_csv('modified_' + original_csv, index=False)
database['modified'] = mod_texts
database.to_csv('modified.csv', index = False)
# Out:
# Time 170: 35.18050289154053
# Time 171: 11.49396562576294
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21884/3944444604.py in <module>
#       2     i += 170
#       3     start = time.time()
# ----> 4     mod_texts[i] = normalize_text(text)
#       5     end = time.time()
#       6     print("Time {}: {}".format(i, end - start))
#
# ~\AppData\Local\Temp/ipykernel_21884/1235626188.py in normalize_text(text)
#      55
#      56 def normalize_text(text):
# ---> 57     words = re.split('[<>()\[\]{}|\\/-_,.;:!?\"\' \n\t]', text)
#      58     normalized = filter_and_normalize(words, extract_prefix)
#      59 #     print(normalized)
#
# ~\AppData\Local\Programs\Python\Python39\lib\re.py in split(pattern, string, maxsplit, flags)
#     229     and the remainder of the string is returned as the final element
#     230     of the list."""
# --> 231     return _compile(pattern, flags).split(string, maxsplit)
#     232
#     233 def findall(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
for i, text in enumerate(texts[:5]):
    if mod_texts[i] != '':
        print(mod_texts[i])
        print(i)
# Out:
# kompànija dȍstava hrána oor ash olt poslovánje ur rázdōblje normalizácija potrážnja pandemij bu otraž ȕsluga hrána pandèmija cov mjȅsec priprema konsolidácija sȅktor eut ransa milìjārda èuro mer oor kúpnja ol transàkcija milìjārda èuro nȕžda diòničār Fȋnskā tvȑtka diònīk rijed oor ash diònica sklȍp transàkcija dȍlār Pȃd diònīk sȕ dvȉje kompànija oor ash transàkcija tȑžīšte an Švȅdskā rva rb olt gȍdina elsin međuvrijéme ur zi tìsuća pȁrtner restòrān tvȑtka návod eut olt im kòrisnīk in kompànija krȃj kòrisnīk oor ash krȃj tròmjesēčje prètplatnīk ȕsluga druži snága ol nȃm ràzina fókus priopćénje objavlje útorak šȅf1 tvȑtka ony ot dvȉje trećìna vrijédnōst olt nárudžba pokàzatelj koja ukl vrijédnōst nárudžba pretplat ȕsluga dȍprinos sȕ tvȑtka dètālj     gȍdina zȃrada dȍlār ransa polòvina gȍdina ol oor as prilagođ ráspon nȕla dȍlār oor ash príhod tròmjesēčje milìjārda dȍlār
# 0
# vrhúnac karijéra svijȇt ténis svo brȏnca limpi ìgra av ćȕp gȍdina ìgrāč svijȇt karijéra bȍlēst rȁzgovōr -o emìsija filmu op trenútak žìvot žìvot kàrtōn spòrtāš nč gȏd žȉva -u all tre rvats fakùltēt olumb   žìvot kàrtōn brazo bȉlo kljẉč sànšu žìvot ténis mao zȇlje bȅz obrazovánje bȉlo reprezentatívac pȕt tenìsāč prìprāvnīk pȁrtner fȍnd òrao ȇgo rȇd spȍrt omo úspon Pȃdova počétak náčin ténis reb pròblēm sȁv rvats asn neplanir -u aže rázvoj gȏd bànka òda psihijàtrija ao tenìsāč ra láma2 ìgra tùrnīr sȁv gȍdina ȍzljeda bȍlēst ro vrijéme opòravak Pȃd bólnica tèrēn Ȍslo trenútak vrijéme sȋ vrijéme od Dàniel krèvet aže svijȇt mononukleóza áda ost spòrtāš opòravak trenàžēr oli žìvot pòtpunōst bȉlo sȕ pròblēm zdrȃvlje is tȉp gȍdina Sàti trenàžēr teretàna mȅč tóga krèvet gȍdina Dàniel spȍrt noš tràuma tio ìgra pokrètač áda ȉzazōv bȁš2 spȍrt ek se ìmām pròblēm stȍtina karijéra nč mpo éra Đokov ad ede obi počélo spȍrt prijatèljstvo tȋm2 čȍvjek mjȅsec sezóna ȍbzīr sùpārnīk tèrēn vèčera píće
#  'vrhúnac karijéra svijȇt ténis svo brȏnca limpi ìgra av ćȕp gȍdina ìgrāč svijȇt karijéra bȍlēst rȁzgovōr -o emìsija filmu\xa0op trenútak žìvot žìvot kàrtōn spòrtāš nč gȏd žȉva -u all tre rvats fakùltēt olumb \xa0 žìvot kàrtōn brazo bȉlo kljẉč sànšu žìvot ténis mao zȇlje bȅz obrazovánje bȉlo reprezentatívac pȕt tenìsāč prìprāvnīk pȁrtner fȍnd òrao ȇgo rȇd spȍrt omo úspon Pȃdova počétak náčin ténis reb pròblēm sȁv rvats asn neplanir -u aže rázvoj gȏd bànka òda psihijàtrija ao tenìsāč ra láma2 ìgra tùrnīr sȁv gȍdina ȍzljeda bȍlēst ro vrijéme opòravak Pȃd bólnica tèrēn Ȍslo trenútak vrijéme sȋ vrijéme od Dàniel krèvet aže svijȇt mononukleóza áda ost spòrtāš opòravak trenàžēr oli žìvot pòtpunōst bȉlo sȕ pròblēm zdrȃvlje is tȉp gȍdina Sàti trenàžēr teretàna mȅč tóga krèvet gȍdina Dàniel spȍrt noš tràuma tio ìgra pokrètač áda ȉzazōv bȁš2 spȍrt ek se ìmām pròblēm stȍtina karijéra nč mpo éra Đokov ad ede obi počélo spȍrt prijatèljstvo tȋm2 čȍvjek mjȅsec sezóna ȍbzīr sùpārnīk tèrēn vèčera píće \xa0',
#  'Rùmūnjskā bólnica mjȅsto  (I) tijȇlo vrȅća hodniku\xa0 ukure tot mjȅsec umunj pogođ zèmlja ov vȁla vírus ose ov vȁla ur zȃpad ur umunj zemlj ur Pȃd stu smȑtnōst \xa0 umunj lijȇčnīk sȕ umunj sèlo je ata irs šȅf1 bólnica ukure tjȅdan Mjȅsēc eće sèlo dȍdo dje strȕčnjāk su brȏj slȕčāj stòpa cijeplje umunj ìznos òkno \xa0da prȍsjeka uro scrpl irs sȁv krȃj Dàniel stvȃr nesposóbnōst stanovníštvo mȍra ek bȉlo vȁla bȉlo stanovníštvo \xa0 umunj brȏj slȕčāj pandèmija slȕčāj cov - % renut pacìjent obolj cov zèmlja njȅga2 ȍsoba koronavi počétak pandèmija \xa0',
#  'ake àvlija pròsinac1 omm ur brȁt pẕvāk ys predb superzvi líga -a er ill ra rostr ll- Tȃr ìgrāč pẕvāk ill -godi líga tȁh azz ew er roo et al level locko ešikt ri ll- Tȃr ùtakmica pètōrka reprezentácija zlȃto eki ond ari prósjek pòēn asistèncija ùtakmica sezóna Prȇko pòēn rekòrdēr člȃn mòmče -ih gȍdina Dàniel run back rȉng2 težìna grànica kg -u sȁv gȏd ranci ers rȏ1 ow ll- tȁra dȅsetljeće -u ari ùtakmica run bac pȍvijēst líga ra bo now fi fi was annou aga fòrmer er ill st fr eptem hȉs li ht gt pȉc twi boj dèbī bòrba rȕnda àvlija pȕt bòksāč1 la šȍu  (I) vȅčēr ȍkršāj ak àula sȁv pròtīvnīk rȉng2 - koléga youtu sȏn iba zakuc at obins tȇ bórac skr yr oodle om ury bȉt pròtīvnīk iskústvo bȍks1 ȑt ys ur mȅč bȁš2 fùnkcija predb au mȅč oodle']

# %%
database['modified'] = mod_texts

# %%
database['modified'] = mod_texts
database.to_csv('modified.csv', index = False)
